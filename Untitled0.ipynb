# %% [markdown]
# <a href="https://colab.research.google.com/github/sewasewT7/10Acadamy/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install kaggle

# %%
#configuring the path of kaggle.json file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# importing dog vs cat dataset from kaggle

# %%
# !kaggle competitions download -c dogs-vs-cats
# Out:
# 403 - Forbidden - You must accept this competition's rules before you'll be able to download files.

# %%
# !kaggle competitions download -c dogs-vs-cats
# Out:
# 403 - Forbidden - You must accept this competition's rules before you'll be able to download files.

# %%
# !kaggle competitions download -c dogs-vs-cats
# Out:
# ...
#  99% 807M/812M [00:11<00:00, 159MB/s]
# 100% 812M/812M [00:11<00:00, 73.1MB/s]

# %%
# !ls
# Out:
# dogs-vs-cats.zip  kaggle.json  sample_data  sampleSubmission.csv  test1.zip  train.zip

# %%
#extracting the compressed dataset
from zipfile import ZipFile

dataset = 'dogs-vs-cats.zip'

with ZipFile(dataset, 'r') as zip:
  zip.extractall()
  print("extracted")
# Out:
# extracted

# %%
#extracting the compressed dataset for train file
from zipfile import ZipFile

dataset = '/content/train.zip'

with ZipFile(dataset, 'r') as zip:
  zip.extractall()
  print('Extracted')
# Out:
# Extracted

# %%
import os
#counting the number of the file in the train folder
path, dirs, files = next(os.walk('/content/train'))
file_count = len(files)
print('number of images:', file_count )
# Out:
# number of images: 25000

# %% [markdown]
# print the name of images

# %%
file_names = os.listdir('/content/train')
print(file_names)
# Out:
# ['dog.7756.jpg', 'dog.7211.jpg', 'dog.9665.jpg', 'dog.4528.jpg', 'dog.7169.jpg', 'cat.5131.jpg', 'cat.12327.jpg', 'dog.11666.jpg', 'dog.5200.jpg', 'cat.5663.jpg', 'cat.970.jpg', 'cat.11503.jpg', 'cat.7556.jpg', 'dog.5451.jpg', 'dog.11427.jpg', 'dog.98.jpg', 'cat.1324.jpg', 'dog.3312.jpg', 'cat.1721.jpg', 'dog.4452.jpg', 'cat.744.jpg', 'dog.8206.jpg', 'cat.9816.jpg', 'dog.8050.jpg', 'cat.1604.jpg', 'dog.2335.jpg', 'dog.4817.jpg', 'cat.10426.jpg', 'cat.9004.jpg', 'dog.246.jpg', 'dog.10021.jpg', 'cat.10333.jpg', 'dog.2265.jpg', 'cat.10017.jpg', 'cat.12233.jpg', 'dog.11987.jpg', 'dog.396.jpg', 'cat.10066.jpg', 'cat.2279.jpg', 'dog.4489.jpg', 'cat.4571.jpg', 'cat.7469.jpg', 'cat.3771.jpg', 'dog.4167.jpg', 'dog.8945.jpg', 'dog.8344.jpg', 'cat.7712.jpg', 'cat.8506.jpg', 'cat.6319.jpg', 'dog.10682.jpg', 'dog.560.jpg', 'dog.8589.jpg', 'dog.11592.jpg', 'dog.2999.jpg', 'dog.4649.jpg', 'cat.3744.jpg', 'cat.3530.jpg', 'cat.10736.jpg', 'cat.2166.jpg', 'cat.12492.jpg', 'cat.9653.jpg', 'dog.9222.jpg
# ...

# %% [markdown]
# Imporing reauired Dependencies

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split
from google.colab.patches import cv2_imshow

# %% [markdown]
# Displayin both images

# %%
#display dog image
img = mpimg.imread('/content/train/dog.10021.jpg')
imgplt = plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('/content/train/cat.12233.jpg')
imgplt = plt.imshow(img)
plt.show()

# %%
files_name = os.listdir('/content/train')

for i in range(5):
  name = file_names[i]
  print(name[0:3])
# Out:
# dog
# dog
# dog
# dog
# dog

# %%
files_name = os.listdir('/content/train')
dog_count = 0
cat_count = 0

for img_files in file_names:
  name = img_files[0:3]

  if name == 'dog':
    dog_count += 1
  else:
    cat_count += 1
print("number of dogs are: ", dog_count)
print("number of cats are: ", cat_count)
# Out:
# number of dogs are:  12500
# number of cats are:  12500

# %% [markdown]
# Resizing all the images

# %%
#Creating a directory for ewsized images
